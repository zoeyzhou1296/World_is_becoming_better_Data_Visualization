# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Notability/UChicago_Q2_Winter_2022/PPHA Data visualization/DV_FP/
# Out:
# /content/drive/MyDrive/Notability/UChicago_Q2_Winter_2022/PPHA Data visualization/DV_FP

# %%
BASE_PATH = "/content/drive/MyDrive/Notability/UChicago_Q2_Winter_2022/PPHA Data visualization/DV_FP/"

# %%
summary = pd.read_csv(filepath_or_buffer = BASE_PATH + 'DV_FP_data_summary.csv')
summary
# Out:
#     Region, subregion, country or area *  Country code  Parent code  \
# 0                                Burundi           108          910
# 1                                Comoros           174          910
# 2                               Djibouti           262          910
# 3                                Eritrea           232          910
# 4                               Ethiopia           231          910
# ..                                   ...           ...          ...
# 258                              Bermuda            60          918
# 259                               Canada           124          918
# 260                            Greenland           304          918
# 261            Saint Pierre and Miquelon           666          918
# 262             United States of America           840          918
#
#     1950-1955 pop 2015-2020 pop
# 0           2 403        11 012
# 1             166           823
# 2              65           951
# ...

# %%
fert_mort= pd.read_csv(filepath_or_buffer = BASE_PATH + 'DV_FP_data _FERT_MORT.csv')
fert_mort.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country code    201 non-null    int64
#  1   1950-1955 fert  201 non-null    float64
#  2   2015-2020 fert  201 non-null    float64
#  3   1950-1955 mort  201 non-null    int64
#  4   2015-2020 mort  201 non-null    int64
# dtypes: float64(2), int64(3)
# memory usage: 8.0 KB

# %%
df=fert_mort.merge(summary,on='Country code', how='left')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 201 entries, 0 to 200
# Data columns (total 9 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Country code                          201 non-null    int64
#  1   1950-1955 fert                        201 non-null    float64
#  2   2015-2020 fert                        201 non-null    float64
#  3   1950-1955 mort                        201 non-null    int64
#  4   2015-2020 mort                        201 non-null    int64
#  5   Region, subregion, country or area *  201 non-null    object
#  6   Parent code                           201 non-null    int64
#  7   1950-1955 pop                         201 non-null    object
#  8   2015-2020 pop                         201 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 15.7+ KB

# %%
df['Parent code'].value_counts()
# Out:
# 910     20
# 922     18
# 915     17
# 914     16
# 931     13
# 925     12
# 924     11
# 920     11
# 923     10
# 911      9
# 5501     9
# 916      8
# 906      8
# 912      7
# 926      7
# 928      5
# 5500     5
# 913      5
# 954      3
# 957      3
# 927      2
# 918      2
# Name: Parent code, dtype: int64

# %%
df.loc[(df['Parent code']==911),'Parent code']=910
df.loc[(df['Parent code']==913),'Parent code']=910
df.loc[(df['Parent code']==914),'Parent code']=910
df.loc[(df['Parent code']==912),'Parent code']=910

df.loc[(df['Parent code']==5501),'Parent code']=5500
df.loc[(df['Parent code']==906),'Parent code']=5500
df.loc[(df['Parent code']==902),'Parent code']=5500

df.loc[(df['Parent code']==916),'Parent code']=915
df.loc[(df['Parent code']==931),'Parent code']=915

df.loc[(df['Parent code']==954),'Parent code']=928
df.loc[(df['Parent code']==957),'Parent code']=928
df.loc[(df['Parent code']==922),'Parent code']=5500
df.loc[(df['Parent code']==920),'Parent code']=5500
df.loc[(df['Parent code']==924),'Parent code']=925
df.loc[(df['Parent code']==923),'Parent code']=925
df.loc[(df['Parent code']==926),'Parent code']=925

df.loc[(df['Parent code']==927),'Parent code']=928

df.loc[(df['Parent code']==918),'Parent code']=915

# %%
cols=['country_code','fert_1950_1955','fert_2015_2020','mort_1950_1955','mort_2015_2020','country_name','parent_code','pop_1950_1955','pop_2015_2020']

# %%
df.columns=cols

# %%
df
# Out:
#      country_code  fert_1950_1955  fert_2015_2020  mort_1950_1955  \
# 0             108            6.80            5.45             280
# 1             174            6.00            4.24             288
# 2             262            6.31            2.76             260
# 3             232            6.97            4.10             333
# 4             231            7.17            4.30             333
# ..            ...             ...             ...             ...
# 196           442            1.98            1.45              56
# 197           528            3.05            1.66              30
# 198           756            2.31            1.54              36
# 199           124            3.65            1.53              44
# 200           840            3.31            1.78              35
#
#      mort_2015_2020              country_name  parent_code pop_1950_1955  \
# 0                63                   Burundi          910         2 403
# ...

# %%
df.loc[(df['parent_code']==910),'parent_code']='Africa'
df.loc[(df['parent_code']==915),'parent_code']='America'
df.loc[(df['parent_code']==5500),'parent_code']='Asia'
df.loc[(df['parent_code']==925),'parent_code']='Europe'
df.loc[(df['parent_code']==928),'parent_code']='Oceania'
df.loc[(df['country_code']==840),'parent_code']='US'
df.loc[(df['country_code']==156),'parent_code']='China'

# %%
df['parent_code'].value_counts()
# Out:
# Africa     57
# Asia       50
# Europe     40
# America    39
# Oceania    13
# China       1
# US          1
# Name: parent_code, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 201 entries, 0 to 200
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   country_code    201 non-null    int64
#  1   fert_1950_1955  201 non-null    float64
#  2   fert_2015_2020  201 non-null    float64
#  3   mort_1950_1955  201 non-null    int64
#  4   mort_2015_2020  201 non-null    int64
#  5   country_name    201 non-null    object
#  6   parent_code     201 non-null    object
#  7   pop_1950_1955   201 non-null    object
#  8   pop_2015_2020   201 non-null    object
# dtypes: float64(2), int64(3), object(4)
# memory usage: 15.7+ KB

# %%
df=df.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 201 entries, 0 to 200
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   country_code    201 non-null    int64
#  1   fert_1950_1955  201 non-null    float64
#  2   fert_2015_2020  201 non-null    float64
#  3   mort_1950_1955  201 non-null    int64
#  4   mort_2015_2020  201 non-null    int64
#  5   country_name    201 non-null    object
#  6   parent_code     201 non-null    object
#  7   pop_1950_1955   201 non-null    object
#  8   pop_2015_2020   201 non-null    object
# dtypes: float64(2), int64(3), object(4)
# memory usage: 15.7+ KB

# %%
#df['purchase'].astype(str).astype(int)
#df2['employee_id'] = df2['employee_id'].str.strip()
df['pop_1950_1955']=df['pop_1950_1955'].str.replace(" ","")
df['pop_1950_1955']=df['pop_1950_1955'].astype(str).astype(int)
df['pop_2015_2020']=df['pop_2015_2020'].str.replace(" ","")
df['pop_2015_2020']=df['pop_2015_2020'].astype(str).astype(int)
df.head()
# Out:
#    country_code  fert_1950_1955  fert_2015_2020  mort_1950_1955  \
# 0           108            6.80            5.45             280
# 1           174            6.00            4.24             288
# 2           262            6.31            2.76             260
# 3           232            6.97            4.10             333
# 4           231            7.17            4.30             333
#
#    mort_2015_2020 country_name parent_code  pop_1950_1955  pop_2015_2020
# 0              63      Burundi      Africa           2403          11012
# 1              70      Comoros      Africa            166            823
# 2              51     Djibouti      Africa             65            951
# 3              44      Eritrea      Africa            851           3438
# 4              55     Ethiopia      Africa          18832         107851

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 201 entries, 0 to 200
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   country_code    201 non-null    int64
#  1   fert_1950_1955  201 non-null    float64
#  2   fert_2015_2020  201 non-null    float64
#  3   mort_1950_1955  201 non-null    int64
#  4   mort_2015_2020  201 non-null    int64
#  5   country_name    201 non-null    object
#  6   parent_code     201 non-null    object
#  7   pop_1950_1955   201 non-null    int64
#  8   pop_2015_2020   201 non-null    int64
# dtypes: float64(2), int64(5), object(2)
# memory usage: 15.7+ KB

# %%
df2=df

# %%
df2=df2[df2['pop_1950_1955']>6000]
df2=df2[df2['pop_2015_2020']>10000]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 57 entries, 4 to 200
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   country_code    57 non-null     int64
#  1   fert_1950_1955  57 non-null     float64
#  2   fert_2015_2020  57 non-null     float64
#  3   mort_1950_1955  57 non-null     int64
#  4   mort_2015_2020  57 non-null     int64
#  5   country_name    57 non-null     object
#  6   parent_code     57 non-null     object
#  7   pop_1950_1955   57 non-null     int64
#  8   pop_2015_2020   57 non-null     int64
# dtypes: float64(2), int64(5), object(2)
# memory usage: 4.5+ KB

# %%
df2['parent_code'].value_counts()
# Out:
# Asia       21
# Europe     14
# Africa     11
# America     8
# China       1
# Oceania     1
# US          1
# Name: parent_code, dtype: int64

# %%
df2['fert_1950_1955'].value_counts()
# Out:
# 6.35    2
# 6.75    2
# 7.17    1
# 2.85    1
# 5.40    1
# 4.15    1
# 3.15    1
# 6.10    1
# 4.85    1
# 6.51    1
# 6.95    1
# 3.18    1
# 2.74    1
# 3.63    1
# 3.06    1
# 2.81    1
# 7.42    1
# 2.18    1
# 2.48    1
# 2.36    1
# 3.10    1
# 2.53    1
# 2.37    1
# 2.76    1
# 2.13    1
# 3.05    1
# 3.65    1
# 6.14    1
# 5.49    1
# 6.00    1
# 7.48    1
# 6.34    1
# 6.74    1
# 5.98    1
# 6.05    1
# 7.28    1
# 6.61    1
# 6.65    1
# 7.30    1
# 6.69    1
# 4.41    1
# 5.30    1
# 7.45    1
# 6.36    1
# 5.90    1
# 6.91    1
# 5.96    1
# 6.60    1
# 5.80    1
# 6.11    1
# 6.72    1
# 3.46    1
# 2.96    1
# 5.65    1
# 3.31    1
# Name: fert_1950_1955, dtype: int64

# %%
df2.head(57)
# Out:
#      country_code  fert_1950_1955  fert_2015_2020  mort_1950_1955  \
# 4             231            7.17            4.30             333
# 5             404            7.48            3.52             248
# 10            508            6.34            4.89             319
# 17            834            6.74            4.92             264
# 25            180            5.98            5.96             281
# 33            710            6.05            2.41             228
# 46            566            6.35            5.42             335
# 50             12            7.28            3.05             278
# 51            818            6.75            3.33             387
# 53            504            6.61            2.42             252
# 54            729            6.65            4.43             227
# 62            368            7.30            3.68             327
# 72            792            6.69            2.08             292
# ...

# %%
df2.to_csv('dv_fp.csv', index=False)

# %%
df2['fert_1950_1955'].mean()
# Out:
# 5.095263157894738

# %%
df2['fert_2015_2020'].mean()
# Out:
# 2.361228070175438
